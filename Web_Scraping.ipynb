# %%
from bs4 import BeautifulSoup
import requests

# %%
#url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue'
#page =requests.get(url)
#Soup = BeautifulSoup(page.text, 'html')

#print(Soup)
# Out:
# Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.

# %%
headers = {
    "User-Agent": "MyDataScienceBot/1.0 (your_email@example.com)"
}

url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue'
response = requests.get(url, headers=headers)

#print(response.status_code)
Soup = BeautifulSoup(page.text,'html')
print(Soup)
# Out:
# Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.

# %%
pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 390.1 kB/s eta 0:00:09
#    ----- ---------------------------------- 0.5/4.0 MB 390.1 kB/s eta 0:00:09
#    ----- ---------------------------------- 0.5/4.0 MB 390.1 kB/s eta 0:00:09
#    ------- -------------------------------- 0.8/4.0 MB 459.5 kB/s eta 0:00:08
# ...

# %%
pip install lxml --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\PC\AppData\Local\Programs\Python\Python312\python.exe

# %%
# !{sys.executable} -m pip install lxml html5lib beautifulsoup4
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

headers = {
    "User-Agent": "MyDataScienceBot/1.0 (timothykabira@gmail.com)"
}

url = "https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue"

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

table = soup.find("table", {"class": "wikitable"})

rows = table.find_all("tr")

data = []
for row in rows:
    cols = row.find_all(["td", "th"])
    cols = [col.text.strip() for col in cols]
    data.append(cols)

df = pd.DataFrame(data[1:], columns=data[0])

print(df.head())
# Out:
#   Rank                Name                    Industry Revenue (USD millions)  \
# 0    1             Walmart                      Retail                680,985
# 1    2              Amazon  Retail and cloud computing                637,959
# 2    3  UnitedHealth Group                  Healthcare                400,278
# 3    4               Apple                  Technology                391,035
# 4    5          CVS Health                  Healthcare                372,809
#
#   Revenue growth  Employees              Headquarters
# 0           5.1%  2,100,000     Bentonville, Arkansas
# 1          11.0%  1,556,000       Seattle, Washington
# 2           7.7%    400,000     Minnetonka, Minnesota
# 3           2.0%    164,000     Cupertino, California
# 4           4.2%    259,500  Woonsocket, Rhode Island

# %%
#table = soup.find_all("table", {"class": "wikitable"})
table=soup.find_all('table')
print(table)
# Out:
# [<table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td>Retail
# </td>
# <td style="text-align:center;">680,985
# </td>
# <td style="text-align:center;"><span typeof="mw:File"><span title="Increase"><img alt="Increase" class="mw-file-element" data-file-height="300" data-file-width="300" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/40px-Increase2.svg.png 2x" width="11"/></span></span> <span data-sort-value="7000300000000000000♠" style="display:none"></span> 5.1%
# </td>
# <td style="text-align:center;">2,100,000
# </td>
# ...

# %%
table = soup.find('table', {'class': 'wikitable'})

world_titles = [th.text.strip() for th in table.find_all('th')]

print(world_titles)
# Out:
# ['Rank', 'Name', 'Industry', 'Revenue (USD millions)', 'Revenue growth', 'Employees', 'Headquarters']

# %%
#world_table_titles=[title.text for title in world_titles]
#print(world_table_titles)

# %%
#world_table_titles=[title.text.strip() for title in world_titles]
#print(world_table_titles)

# %%
#table = soup.find_all("table", {"class": "wikitable"})[1]
#print(table)

# %%
#Soup.find('table',class ='wikitable sortable')

#table = soup.find("table", class_="wikitable sortable")
#print(table)

# %%
#table = Soup.find_all('table')[1]

#tables = soup.find_all("table")
#print(len(tables))   # see how many tables BeautifulSoup actually found

# %%
#print(response.status_code)    # should be 200
#print(response.text[:500])     # preview first 500 characters

# %%
# Find all headers
headers_list = soup.find_all('th')
for h in headers_list[:]:  # preview first 10
    print(h.text.strip())
# Out:
# Rank
# Name
# Industry
# Revenue (USD millions)
# Revenue growth
# Employees
# Headquarters
# Rank
# Name
# Industry
# Revenue (USD billions)
# Employees
# Headquarters
# Rank
# Name
# Industry
# Profits(USD millions)
# Headquarters

# %%
df=pd.DataFrame(columns = world_titles)
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue (USD millions), Revenue growth, Employees, Headquarters]
# Index: []

# %%
table.find_all('tr')
# Out:
# [<tr>
#  <th>Rank
#  </th>
#  <th>Name
#  </th>
#  <th>Industry
#  </th>
#  <th>Revenue <br/>(USD millions)
#  </th>
#  <th>Revenue growth
#  </th>
#  <th>Employees
#  </th>
#  <th>Headquarters
#  </th></tr>,
#  <tr>
#  <td>1
#  </td>
#  <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
#  </td>
#  <td>Retail
#  </td>
#  <td style="text-align:center;">680,985
#  </td>
#  <td style="text-align:center;"><span typeof="mw:File"><span title="Increase"><img alt="Increase" class="mw-file-element" data-file-height="300" data-file-width="300" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/40px-Increase2.svg.png 2x" width="11"/></span></span> <span data-sort-value="7000300000000000000♠" style="display:none"></span> 5.1%
#  </td>
#  <td style="text-align:center;">2,100,000
#  </td>
# ...

# %%
column_data=table.find_all('tr')

# %%
for row in column_data:
    row_data=row.find_all('td')
    individual_row_data=[data.text.strip() for data in row_data]
    print(individual_row_data)
# Out:
# []
# ['1', 'Walmart', 'Retail', '680,985', '5.1%', '2,100,000', 'Bentonville, Arkansas']
# ['2', 'Amazon', 'Retail and cloud computing', '637,959', '11.0%', '1,556,000', 'Seattle, Washington']
# ['3', 'UnitedHealth Group', 'Healthcare', '400,278', '7.7%', '400,000', 'Minnetonka, Minnesota']
# ['4', 'Apple', 'Technology', '391,035', '2.0%', '164,000', 'Cupertino, California']
# ['5', 'CVS Health', 'Healthcare', '372,809', '4.2%', '259,500', 'Woonsocket, Rhode Island']
# ['6', 'Berkshire Hathaway', 'Conglomerate', '371,433', '1.9%', '392,400', 'Omaha, Nebraska']
# ['7', 'Alphabet', 'Technology and cloud computing', '350,018', '13.9%', '183,323', 'Mountain View, California']
# ['8', 'Exxon Mobil', 'Petroleum', '349,595', '1.5%', '60,900', 'Spring, Texas']
# ['9', 'McKesson Corporation', 'Healthcare', '308,951', '11.7%', '48,000', 'Irving, Texas']
# ['10', 'Cencora', 'Pharmacy wholesale', '293,959', '12.1%', '44,000', 'Conshohocken, Pennsylvania']
# ...

# %%
for row in column_data:
    row_data=row.find_all('td')
    individual_row_data=[data.text.strip() for data in row_data]
print(individual_row_data)
# Out:
# ['100', 'Eli Lilly', 'Pharmaceutical', '45,043', '32.0%', '47,000', 'Indianapolis, Indiana']

# %%
column_data=table.find_all('tr')

# %%
for row in column_data:
    row_data=row.find_all('td')
    individual_row_data=[data.text.strip() for data in row_data]
    print(individual_row_data)
    #length=len(df)
    #df.loc[length]=individual_row_data
    #print(individual_row_data)
# Out:
# []
# ['1', 'Walmart', 'Retail', '680,985', '5.1%', '2,100,000', 'Bentonville, Arkansas']
# ['2', 'Amazon', 'Retail and cloud computing', '637,959', '11.0%', '1,556,000', 'Seattle, Washington']
# ['3', 'UnitedHealth Group', 'Healthcare', '400,278', '7.7%', '400,000', 'Minnetonka, Minnesota']
# ['4', 'Apple', 'Technology', '391,035', '2.0%', '164,000', 'Cupertino, California']
# ['5', 'CVS Health', 'Healthcare', '372,809', '4.2%', '259,500', 'Woonsocket, Rhode Island']
# ['6', 'Berkshire Hathaway', 'Conglomerate', '371,433', '1.9%', '392,400', 'Omaha, Nebraska']
# ['7', 'Alphabet', 'Technology and cloud computing', '350,018', '13.9%', '183,323', 'Mountain View, California']
# ['8', 'Exxon Mobil', 'Petroleum', '349,595', '1.5%', '60,900', 'Spring, Texas']
# ['9', 'McKesson Corporation', 'Healthcare', '308,951', '11.7%', '48,000', 'Irving, Texas']
# ['10', 'Cencora', 'Pharmacy wholesale', '293,959', '12.1%', '44,000', 'Conshohocken, Pennsylvania']
# ...

# %%
for row in column_data[1:]:
    row_data=row.find_all('td')
    individual_row_data=[data.text.strip() for data in row_data]
    print(individual_row_data)
    #length=len(df)
    #df.loc[length]=individual_row_data
    #print(individual_row_data)
# Out:
# ['1', 'Walmart', 'Retail', '680,985', '5.1%', '2,100,000', 'Bentonville, Arkansas']
# ['2', 'Amazon', 'Retail and cloud computing', '637,959', '11.0%', '1,556,000', 'Seattle, Washington']
# ['3', 'UnitedHealth Group', 'Healthcare', '400,278', '7.7%', '400,000', 'Minnetonka, Minnesota']
# ['4', 'Apple', 'Technology', '391,035', '2.0%', '164,000', 'Cupertino, California']
# ['5', 'CVS Health', 'Healthcare', '372,809', '4.2%', '259,500', 'Woonsocket, Rhode Island']
# ['6', 'Berkshire Hathaway', 'Conglomerate', '371,433', '1.9%', '392,400', 'Omaha, Nebraska']
# ['7', 'Alphabet', 'Technology and cloud computing', '350,018', '13.9%', '183,323', 'Mountain View, California']
# ['8', 'Exxon Mobil', 'Petroleum', '349,595', '1.5%', '60,900', 'Spring, Texas']
# ['9', 'McKesson Corporation', 'Healthcare', '308,951', '11.7%', '48,000', 'Irving, Texas']
# ['10', 'Cencora', 'Pharmacy wholesale', '293,959', '12.1%', '44,000', 'Conshohocken, Pennsylvania']
# ...

# %%
for row in column_data[1:]:
    row_data=row.find_all('td')
    individual_row_data=[data.text.strip() for data in row_data]

    length=len(df)
    df.loc[length]=individual_row_data
    #print(individual_row_data)

# %%
df
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart                      Retail
# 1     2              Amazon  Retail and cloud computing
# 2     3  UnitedHealth Group                  Healthcare
# 3     4               Apple                  Technology
# 4     5          CVS Health                  Healthcare
# ..  ...                 ...                         ...
# 95   96    General Dynamics       Aerospace and defense
# 96   97           Coca-Cola                    Beverage
# 97   98                TIAA                  Financials
# 98   99           Travelers                   Insurance
# 99  100           Eli Lilly              Pharmaceutical
#
#    Revenue (USD millions) Revenue growth  Employees              Headquarters
# 0                 680,985           5.1%  2,100,000     Bentonville, Arkansas
# 1                 637,959          11.0%  1,556,000       Seattle, Washington
# ...

# %%
df.to_csv(r'C:\Users\PC\Documents\Web_Scraping\Companies.csv',index=False)

# %%
for row in table.find_all('tr'):
    cells = row.find_all('td')
    cell_text = [cell.text.strip() for cell in cells]
    if cell_text:
        data.append(cell_text)

# If you want headers from the table
headers = [th.text.strip() for th in table.find_all('th')]
df = pd.DataFrame(data, columns=headers[:len(data[0])])  # adjust header length if needed

print(df.head())
# Out:
#    Rank                Name                    Industry  \
# 0  Rank                Name                    Industry
# 1     1             Walmart                      Retail
# 2     2              Amazon  Retail and cloud computing
# 3     3  UnitedHealth Group                  Healthcare
# 4     4               Apple                  Technology
#
#    Revenue (USD millions)  Revenue growth  Employees           Headquarters
# 0  Revenue (USD millions)  Revenue growth  Employees           Headquarters
# 1                 680,985            5.1%  2,100,000  Bentonville, Arkansas
# 2                 637,959           11.0%  1,556,000    Seattle, Washington
# 3                 400,278            7.7%    400,000  Minnetonka, Minnesota
# 4                 391,035            2.0%    164,000  Cupertino, California

# %%
# Find all headers
column_data=headers_list = soup.find_all('tr')
for h in headers_list[:10]:  # preview first 10
    print(h.text.strip())
# Out:
# Rank
#
# Name
#
# Industry
#
# Revenue (USD millions)
#
# Revenue growth
#
# Employees
#
# Headquarters
# 1
#
# Walmart
#
# Retail
#
# 680,985
#
#   5.1%
#
# 2,100,000
#
# Bentonville, Arkansas
# 2
#
# Amazon
#
# Retail and cloud computing
#
# 637,959
#
#   11.0%
#
# 1,556,000
#
# Seattle, Washington
# 3
#
# UnitedHealth Group
#
# Healthcare
#
# 400,278
#
#   7.7%
#
# 400,000
#
# Minnetonka, Minnesota
# 4
#
# Apple
#
# Technology
#
# 391,035
#
#   2.0%
#
# 164,000
#
# Cupertino, California
# 5
#
# CVS Health
#
# Healthcare
#
# 372,809
#
#   4.2%
#
# 259,500
#
# Woonsocket, Rhode Island
# 6
#
# Berkshire Hathaway
#
# Conglomerate
#
# 371,433
#
#   1.9%
#
# 392,400
#
# Omaha, Nebraska
# 7
#
# Alphabet
#
# Technology and cloud computing
#
# 350,018
#
#   13.9%
#
# 183,323
#
# Mountain View, California
# 8
#
# Exxon Mobil
#
# Petroleum
#
# 349,595
#
#   1.5%
#
# 60,900
#
# Spring, Texas
# 9
#
# McKesson Corporation
#
# Healthcare
#
# 308,951
#
#   11.7%
#
# 48,000
#
# Irving, Texas

# %%
print(f"Number of tables found: {len(tables)}")
# Out:
# Number of tables found: 2
